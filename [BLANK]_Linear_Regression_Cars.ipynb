# %% [markdown]
# <a href="https://colab.research.google.com/github/kimkok-UCBerkeleyHaas/Assignments/blob/main/%5BBLANK%5D_Linear_Regression_Cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression: Buying the Right Car 🚗

# %% [markdown]
# Data from the car website [CarDekho](https://www.cardekho.com/) has information on cars, including the price.
#
# You can use that data to make sure you get a good deal on a new car by figuring out exactly how much you should pay for a specific car!
#
# How can you use the data to figure out how much you should pay?
# **Linear Regression**

# %%
#Updated dataset found here: https://www.kaggle.com/datasets/nehalbirla/vehicle-dataset-from-cardekho

# %%
import pandas as pd

data_path  = 'car_dekho.csv'
car_data = pd.read_csv(data_path)

# %%
car_data.head(20)

# %% [markdown]
# * Car_Name: Name of the car.
#
# * Age: Number of years since the car was made.
#
# * Selling_Price: Price the owner wants to sell the car at.
#
# * Kms_Driven: Distance completed by the car in km.
#
# * Fuel_Type: Fuel type of the car.
#
# * Seller_Type: Dealer or an individual.
#
# * Transmission: Manual or automatic.

# %% [markdown]
# ###  How big is our data set?

# %%
# use the 'len' method to see how many rows are in our dataframe
print(len(car_data))

#car_data.shape

# %% [markdown]
# ##  **Visualizing the Data**

# %% [markdown]
# We can look at `selling price` vs. `age`.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x = 'Age', y = 'Selling_Price', data = car_data)

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# We'll use sklearn to run our linear regression below

# %%
import sklearn
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import numpy as np

x = car_data['Age'].values
x = x[:, np.newaxis]
y = car_data['Selling_Price'].values

# set up our model

# set up our train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 42, test_size = 0.3)

# train the model

# %% [markdown]
# You want buy a nice used car. Your car is a 2020 model and the car salesperson offers to sell it for 6.5 lakh. Would you take it?

# %% [markdown]
# We can try to make our model better by using multiple input variables, like `Kms_Driven` and `Transmission`.

# %%
#sns.scatterplot(x = '??', y = '??', data = ??);

# %%
sns.scatterplot(x = 'Kms_Driven', y = 'Selling_Price', data = car_data);

# %%
#sns.catplot(x = '??', y = '??', data = ??, kind = 'swarm')

# %%
sns.catplot(x = 'Transmission', y = 'Selling_Price', data = car_data, kind = 'swarm')

# %%
car_data['TransmissionType'] = car_data['Transmission'].replace({'Manual':1, 'Automatic':0})

# %%
car_data.head(10)

# %%
#x = car_data[['Age', '??', '??']].values

# set up our model

# train the model

# make predictions
#prediction = ??

# %%
x_multi = car_data[['Age', 'TransmissionType', 'Kms_Driven']].values

multiple = linear_model.LinearRegression(fit_intercept = True)

multiple.fit(x_multi, y)
prediction = multiple.predict(x_multi)

# %%
print(x_multi[0])

# %%
#linear_pred=
print(linear_pred)

#multi_pred=
print(multi_pred)

# %%
linear_pred= linear.predict([[5]])
print(linear_pred)

multi_pred= multiple.predict(x_multi[[0]])
print(multi_pred)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Errors for test data
Test_MAE = mean_absolute_error(y, prediction)
Test_MSE = mean_squared_error(y, prediction)
Test_R2_Score = r2_score(y, prediction)

print(Test_MAE, Test_MSE, Test_R2_Score)

# %%
plt.plot([-5,15],[-5,15])
plt.title("Predicted vs. Real Prices")
plt.xlabel("Real price")
plt.ylabel("Predicted price")
plt.plot(y, prediction, '.')
plt.show()

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

car_data['Prediction'] = prediction
print (car_data)
